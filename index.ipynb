# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
# Rename all the columns to lower case
df.columns = df.columns.str.lower()

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
df.rename_axis(None, axis = 1).rename_axis('linename', axis = 0)
# Out:
#             c/a  unit       scp        station linename division        date  \
# linename
# 0          A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1          A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2          A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3          A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4          A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...         ...   ...       ...            ...      ...      ...         ...
# 197620    TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621    TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622    TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623    TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624    TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#               time     desc  entries    exits  num_lines
# linename
# 0         00:00:00  REGULAR  6736067  2283184  num_lines
# 1         04:00:00  REGULAR  6736087  2283188  num_lines
# 2         08:00:00  REGULAR  6736105  2283229  num_lines
# 3         12:00:00  REGULAR  6736180  2283314  num_lines
# 4         16:00:00  REGULAR  6736349  2283384  num_lines
# ...            ...      ...      ...      ...        ...
# 197620    05:00:00  REGULAR     5554      348  num_lines
# 197621    09:00:00  REGULAR     5554      348  num_lines
# 197622    13:00:00  REGULAR     5554      348  num_lines
# 197623    17:00:00  REGULAR     5554      348  num_lines
# 197624    21:00:00  REGULAR     5554      348  num_lines
#
# [197625 rows x 12 columns]

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df = df.reset_index()
df.head()
# Out:
#    index  Level_0  Index   C/A  Unit       Scp Station Linename Division  \
# 0      0        0      0  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1      1        1      1  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2      2        2      2  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3      3        3      3  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4      4        4      4  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#         Date      Time     Desc  Entries    Exits  Num_Lines  Day_Of_Week  \
# 0 2018-08-25  00:00:00  REGULAR  6736067  2283184  num_lines  Day_of_Week
# 1 2018-08-25  04:00:00  REGULAR  6736087  2283188  num_lines  Day_of_Week
# 2 2018-08-25  08:00:00  REGULAR  6736105  2283229  num_lines  Day_of_Week
# 3 2018-08-25  12:00:00  REGULAR  6736180  2283314  num_lines  Day_of_Week
# 4 2018-08-25  16:00:00  REGULAR  6736349  2283384  num_lines  Day_of_Week
#
#    Day_of_Week
# 0  Day_of_Week
# 1  Day_of_Week
# 2  Day_of_Week
# 3  Day_of_Week
# 4  Day_of_Week

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
df['num_lines'] = 'num_lines'

# %% [markdown]
# Write a function to clean column names:

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = col_name.strip().title()
    return cleaned

# %%
# Use the above function to clean the column names
df.columns = [clean(col) for col in df.columns]

# %%
# Check to ensure the column names were cleaned
df.columns
# Out:
# Index(['Index', 'Level_0', 'Index', 'C/A', 'Unit', 'Scp', 'Station',
#        'Linename', 'Division', 'Date', 'Time', 'Desc', 'Entries', 'Exits',
#        'Num_Lines'],
#       dtype='object')

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
df['Date'] = pd.to_datetime(df['Date'])
# Add a new column 'day_of_week' that represents the day of the week 
df['Day_of_Week'] = df['Date'].dt.dayofweek

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('Day_of_Week').sum()
grouped.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped = grouped.reset_index()
# Print the first five rows of grouped
grouped.head()
# Out:
#    Day_of_Week       Index     Level_0       Index        Entries  \
# 0            0  2783610827  2783610827  2783610827  1114237052454
# 1            1  2833413973  2833413973  2833413973  1143313287046
# 2            2  2781528032  2781528032  2781528032  1123655222441
# 3            3  2817391725  2817391725  2817391725  1122723988662
# 4            4  2778112001  2778112001  2778112001  1110224700078
#
#           Exits
# 0  911938153513
# 1  942230721477
# 2  920630864687
# 3  920691927110
# 4  906799065337

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
df['Is_Weekend'] = 'Is_Weekend'
grouped['Is_Weekend'] = grouped['Day_of_Week'].map(weekend_map)

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('Is_Weekend').mean()
wkend[['Entries', 'Exits']].plot(kind='barh')
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
df
# Out:
#          Index  Level_0   Index    C/A  Unit       Scp        Station  \
# 0            0        0       0   A002  R051  02-00-00          59 ST
# 1            1        1       1   A002  R051  02-00-00          59 ST
# 2            2        2       2   A002  R051  02-00-00          59 ST
# 3            3        3       3   A002  R051  02-00-00          59 ST
# 4            4        4       4   A002  R051  02-00-00          59 ST
# ...        ...      ...     ...    ...   ...       ...            ...
# 197620  197620   197620  197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197621  197621   197621  197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197622  197622   197622  197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197623  197623   197623  197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197624  197624   197624  197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT
#
#        Linename Division       Date      Time     Desc  Entries    Exits  \
# 0       NQR456W      BMT 2018-08-25  00:00:00  REGULAR  6736067  2283184
# 1       NQR456W      BMT 2018-08-25  04:00:00  REGULAR  6736087  2283188
# 2       NQR456W      BMT 2018-08-25  08:00:00  REGULAR  6736105  2283229
# 3       NQR456W      BMT 2018-08-25  12:00:00  REGULAR  6736180  2283314
# 4       NQR456W      BMT 2018-08-25  16:00:00  REGULAR  6736349  2283384
# ...         ...      ...        ...       ...      ...      ...      ...
# 197620        R      RIT 2018-08-31  05:00:00  REGULAR     5554      348
# 197621        R      RIT 2018-08-31  09:00:00  REGULAR     5554      348
# 197622        R      RIT 2018-08-31  13:00:00  REGULAR     5554      348
# 197623        R      RIT 2018-08-31  17:00:00  REGULAR     5554      348
# 197624        R      RIT 2018-08-31  21:00:00  REGULAR     5554      348
#
#         Num_Lines  Day_of_Week  Is_Weekend
# 0       num_lines            5  Is_Weekend
# 1       num_lines            5  Is_Weekend
# 2       num_lines            5  Is_Weekend
# 3       num_lines            5  Is_Weekend
# 4       num_lines            5  Is_Weekend
# ...           ...          ...         ...
# 197620  num_lines            4  Is_Weekend
# 197621  num_lines            4  Is_Weekend
# 197622  num_lines            4  Is_Weekend
# 197623  num_lines            4  Is_Weekend
# 197624  num_lines            4  Is_Weekend
#
# [197625 rows x 17 columns]

# %%
# Remove the 'c/a' and 'scp' columns
df = df.drop(['C/A', 'Scp'], axis = 1)
df.head(2)
# Out:
#    Index  Level_0  Index  Unit Station Linename Division       Date      Time  \
# 0      0        0      0  R051   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1      1        1      1  R051   59 ST  NQR456W      BMT 2018-08-25  04:00:00
#
#       Desc  Entries    Exits  Num_Lines  Day_of_Week  Is_Weekend
# 0  REGULAR  6736067  2283184  num_lines            5  Is_Weekend
# 1  REGULAR  6736087  2283188  num_lines            5  Is_Weekend

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here 
could be off since df isn't sorted by this value

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
